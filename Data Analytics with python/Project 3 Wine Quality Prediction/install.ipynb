# %%
pip install numpy matplotlib scipy seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.9 kB 495.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 538.9 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ----------------------------- ---------- 122.9/165.9 kB ? eta -:--:--
#      -------------------------------------- 165.9/165.9 kB 3.4 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...

# %%
pip install plotly bokeh scikit-learn xgboost lightgbm catboost scipy statsmodels
# Out:
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.4 MB 3.2 MB/s eta 0:00:06
#     --------------------------------------- 0.2/16.4 MB 3.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/16.4 MB 4.8 MB/s eta 0:00:04
#    - -------------------------------------- 0.8/16.4 MB 4.9 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/16.4 MB 5.5 MB/s eta 0:00:03
#    --- ------------------------------------ 1.5/16.4 MB 5.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.9/16.4 MB 6.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.3/16.4 MB 6.3 MB/s eta 0:00:03
#    ------ --------------------------------- 2.6/16.4 MB 6.4 MB/s eta 0:00:03
# ...

# %%
pip install skimpy
# Out:
# ...
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      -------------------------------------- 61.0/61.0 kB 806.3 kB/s eta 0:00:00
# ...
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# ...
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.5 MB 3.6 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/15.5 MB 5.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.8/15.5 MB 8.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.4/15.5 MB 7.9 MB/s eta 0:00:02
# ...

# %%
pip install termcolor
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: C:\Users\Divakar\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
